# %% [markdown]
# # Goal
# Kaggle Dataset → CNN Model → Save Model → FastAPI → App Integration

# %% [markdown]
# # Step 1. Verify Dataset Structure

# %%
Dataset_path = "/kaggle/input/datasets/ibrahimagabardiop/pest-ai-ravageur/working/dataset_publish/balanced_pest_dataset"
print(os.listdir(Dataset_path))

# %% [markdown]
# # Step 1. Load Dataset Properly

# %%
import tensorflow as tf

IMG_SIZE = (128, 128)
BATCH_SIZE = 32

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    Dataset_path + "/train",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    Dataset_path + "/val",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    Dataset_path + "/test",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %% [markdown]
# # Step 2. Get Class Names

# %%
class_names =train_data.class_names

print(class_names)
print("Total classes:", len(class_names))

# %% [markdown]
# # Step 3. Visualize Images

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

for images, labels in train_data.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
